# %%
from template_files import adult

df = adult.read_csv_1('data/adult.csv')
df
# Out:
#        age         workclass  education  education-num      marital-status  \
# 0        2         State-gov  Bachelors             13       Never-married
# 1        3  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2        2           Private    HS-grad              9            Divorced
# 3        3           Private       11th              7  Married-civ-spouse
# 4        1           Private  Bachelors             13  Married-civ-spouse
# ...    ...               ...        ...            ...                 ...
# 48837    2           Private  Bachelors             13            Divorced
# 48838    4               NaN    HS-grad              9             Widowed
# 48839    2           Private  Bachelors             13  Married-civ-spouse
# 48840    2           Private  Bachelors             13            Divorced
# 48841    1      Self-emp-inc  Bachelors             13  Married-civ-spouse
#
#               occupation    relationship                race     sex  \
# 0           Adm-clerical   Not-in-family               White    Male
# 1        Exec-managerial         Husband               White    Male
# 2      Handlers-cleaners   Not-in-family               White    Male
# 3      Handlers-cleaners         Husband               Black    Male
# 4         Prof-specialty            Wife               Black  Female
# ...                  ...             ...                 ...     ...
# 48837     Prof-specialty   Not-in-family               White  Female
# 48838                NaN  Other-relative               Black    Male
# 48839     Prof-specialty         Husband               White    Male
# 48840       Adm-clerical       Own-child  Asian-Pac-Islander    Male
# 48841    Exec-managerial         Husband               White    Male
#
#        capitalgain  capitalloss  hoursperweek native-country  class
# 0                1            0             2  United-States  <=50K
# 1                0            0             0  United-States  <=50K
# 2                0            0             2  United-States  <=50K
# 3                0            0             2  United-States  <=50K
# 4                0            0             2           Cuba  <=50K
# ...            ...          ...           ...            ...    ...
# 48837            0            0             2  United-States  <=50K
# 48838            0            0             2  United-States  <=50K
# 48839            0            0             3  United-States  <=50K
# 48840            2            0             2  United-States  <=50K
# 48841            0            0             3  United-States   >50K
#
# [48842 rows x 14 columns]

# %%
print(f'Number of rows: {adult.num_rows(df)}')
print(f'Attribute names: {adult.column_names(df)}')
print(f'Missing attributes: {adult.missing_values(df)}')
print(f'Attributes with at least one missing attribute: {adult.columns_with_missing_values(df)}')
print(f'Percentage of individuals with Bachelors or Masters: {adult.bachelors_masters_percentage(df)}')
# Out:
# Number of rows: 48842
# Attribute names: ['age', 'workclass', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capitalgain', 'capitalloss', 'hoursperweek', 'native-country', 'class']
# Missing attributes: 6465
# Attributes with at least one missing attribute: ['workclass', 'occupation', 'native-country']
# Percentage of individuals with Bachelors or Masters: 21.9

# %%
df_no_na = adult.data_frame_without_missing_values(df)
df_no_na
# Out:
#        age         workclass  education  education-num      marital-status  \
# 0        2         State-gov  Bachelors             13       Never-married
# 1        3  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2        2           Private    HS-grad              9            Divorced
# 3        3           Private       11th              7  Married-civ-spouse
# 4        1           Private  Bachelors             13  Married-civ-spouse
# ...    ...               ...        ...            ...                 ...
# 48836    1           Private  Bachelors             13       Never-married
# 48837    2           Private  Bachelors             13            Divorced
# 48839    2           Private  Bachelors             13  Married-civ-spouse
# 48840    2           Private  Bachelors             13            Divorced
# 48841    1      Self-emp-inc  Bachelors             13  Married-civ-spouse
#
#               occupation   relationship                race     sex  \
# 0           Adm-clerical  Not-in-family               White    Male
# 1        Exec-managerial        Husband               White    Male
# 2      Handlers-cleaners  Not-in-family               White    Male
# 3      Handlers-cleaners        Husband               Black    Male
# 4         Prof-specialty           Wife               Black  Female
# ...                  ...            ...                 ...     ...
# 48836     Prof-specialty      Own-child               White    Male
# 48837     Prof-specialty  Not-in-family               White  Female
# 48839     Prof-specialty        Husband               White    Male
# 48840       Adm-clerical      Own-child  Asian-Pac-Islander    Male
# 48841    Exec-managerial        Husband               White    Male
#
#        capitalgain  capitalloss  hoursperweek native-country  class
# 0                1            0             2  United-States  <=50K
# 1                0            0             0  United-States  <=50K
# 2                0            0             2  United-States  <=50K
# 3                0            0             2  United-States  <=50K
# 4                0            0             2           Cuba  <=50K
# ...            ...          ...           ...            ...    ...
# 48836            0            0             2  United-States  <=50K
# 48837            0            0             2  United-States  <=50K
# 48839            0            0             3  United-States  <=50K
# 48840            2            0             2  United-States  <=50K
# 48841            0            0             3  United-States   >50K
#
# [45222 rows x 14 columns]

# %%
df_one_hot = adult.one_hot_encoding(df)
df_one_hot
# Out:
#        education-num  age_0  age_1  age_2  age_3  age_4  \
# 0                 13  False  False   True  False  False
# 1                 13  False  False  False   True  False
# 2                  9  False  False   True  False  False
# 3                  7  False  False  False   True  False
# 4                 13  False   True  False  False  False
# ...              ...    ...    ...    ...    ...    ...
# 48836             13  False   True  False  False  False
# 48837             13  False  False   True  False  False
# 48839             13  False  False   True  False  False
# 48840             13  False  False   True  False  False
# 48841             13  False   True  False  False  False
#
#        workclass_Federal-gov  workclass_Local-gov  workclass_Private  \
# 0                      False                False              False
# 1                      False                False              False
# 2                      False                False               True
# 3                      False                False               True
# 4                      False                False               True
# ...                      ...                  ...                ...
# 48836                  False                False               True
# 48837                  False                False               True
# 48839                  False                False               True
# 48840                  False                False               True
# 48841                  False                False              False
#
#        workclass_Self-emp-inc  ...  native-country_Portugal  \
# 0                       False  ...                    False
# 1                       False  ...                    False
# 2                       False  ...                    False
# 3                       False  ...                    False
# 4                       False  ...                    False
# ...                       ...  ...                      ...
# 48836                   False  ...                    False
# 48837                   False  ...                    False
# 48839                   False  ...                    False
# 48840                   False  ...                    False
# 48841                    True  ...                    False
#
#        native-country_Puerto-Rico  native-country_Scotland  \
# 0                           False                    False
# 1                           False                    False
# 2                           False                    False
# 3                           False                    False
# 4                           False                    False
# ...                           ...                      ...
# 48836                       False                    False
# 48837                       False                    False
# 48839                       False                    False
# 48840                       False                    False
# 48841                       False                    False
#
#        native-country_South  native-country_Taiwan  native-country_Thailand  \
# 0                     False                  False                    False
# 1                     False                  False                    False
# 2                     False                  False                    False
# 3                     False                  False                    False
# 4                     False                  False                    False
# ...                     ...                    ...                      ...
# 48836                 False                  False                    False
# 48837                 False                  False                    False
# 48839                 False                  False                    False
# 48840                 False                  False                    False
# 48841                 False                  False                    False
#
#        native-country_Trinadad&Tobago  native-country_United-States  \
# 0                               False                          True
# 1                               False                          True
# 2                               False                          True
# 3                               False                          True
# 4                               False                         False
# ...                               ...                           ...
# 48836                           False                          True
# 48837                           False                          True
# 48839                           False                          True
# 48840                           False                          True
# 48841                           False                          True
#
#        native-country_Vietnam  native-country_Yugoslavia
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
# ...                       ...                        ...
# 48836                   False                      False
# 48837                   False                      False
# 48839                   False                      False
# 48840                   False                      False
# 48841                   False                      False
#
# [45222 rows x 119 columns]

# %%
df_label_encoding = adult.label_encoding(df)
df_label_encoding
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 45217    0
# 45218    0
# 45219    0
# 45220    0
# 45221    1
# Name: class, Length: 45222, dtype: int32

# %%
df_label_encoding
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 45217    0
# 45218    0
# 45219    0
# 45220    0
# 45221    1
# Name: class, Length: 45222, dtype: int32

# %%
y_pred = adult.dt_predict(df_one_hot, df_label_encoding)
y_pred
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 45217    0
# 45218    0
# 45219    1
# 45220    0
# 45221    1
# Length: 45222, dtype: int32

# %%
df_label_encoding
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 45217    0
# 45218    0
# 45219    0
# 45220    0
# 45221    1
# Name: class, Length: 45222, dtype: int32

# %%
import pandas as pd
y_true = df_label_encoding
adult.dt_error_rate(y_pred, y_true)
# Out:
# 0.08279156162929546
