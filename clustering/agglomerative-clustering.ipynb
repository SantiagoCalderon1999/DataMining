# %% [markdown]
# ## Agglomerative clustering

# %%
import sklearn.datasets as data
import matplotlib.pyplot as plt

X, clusters = data.make_blobs(n_samples=1000, n_features=2, cluster_std=1.0, random_state=1)

# %%
import sklearn.cluster as cluster
import sklearn.metrics as metrics
from scripts.clustering_plotting import plot_cluster
import numpy as np

        
for k in range(2, 10):
    ac = cluster.AgglomerativeClustering(n_clusters = k, linkage='average', affinity='euclidean')
    ac.fit(X)
    SC = metrics.silhouette_score(X, ac.labels_, metric = 'euclidean')
    CH = metrics.calinski_harabasz_score(X, ac.labels_)
    print(f'k = {k}')
    print(f'Silhouette coefficient: {SC}')
    print(f'Calinski Harabasz: {CH}')
    print()
    colors = []
    for i in range(0, k):
        colors.append(np.random.rand(3,1).flatten())
    plot_cluster(ac.labels_, colors, X, k)
    plt.title(f'K = {k}')
    plt.show()
# Out:
# k = 2
# Silhouette coefficient: 0.7671158342823451
# Calinski Harabasz: 5433.468071587018
# c:\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# c:\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# k = 3
# Silhouette coefficient: 0.7167106735967744
# Calinski Harabasz: 9678.012853127417
# k = 4
# Silhouette coefficient: 0.6112363874682166
# Calinski Harabasz: 6536.898995093239
# c:\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# k = 5
# Silhouette coefficient: 0.5127882892250933
# Calinski Harabasz: 4938.255217703051
# c:\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# c:\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# k = 6
# Silhouette coefficient: 0.41711786583447225
# Calinski Harabasz: 4087.7436591967976
# k = 7
# Silhouette coefficient: 0.3618602616887695
# Calinski Harabasz: 3493.1789575001576
# c:\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# k = 8
# Silhouette coefficient: 0.2876236932152154
# Calinski Harabasz: 3061.968181077719
# c:\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# c:\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# k = 9
# Silhouette coefficient: 0.26532625573347945
# Calinski Harabasz: 2784.9913413942036

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as hierarchy

plt.figure()

Z = np.empty([len(ac.children_), 4], dtype = float)
cluster_distances = np.arange(ac.children_.shape[0])
cluster_sizes = np.arange(2, ac.children_.shape[0] + 2)

for i in range(len(ac.children_)):
    Z[i][0] = ac.children_[i][0]
    Z[i][1] = ac.children_[i][1]
    Z[i][2] = cluster_distances[i]
    Z[i][3] = cluster_sizes[i]
    
hierarchy.dendrogram(Z)
plt.show()
